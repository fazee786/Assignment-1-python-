# %%
print("Twinkle, twinkle, little star, \n\tHow I wonder what you are! \n\t\t\Up above the world so high, \n\ttwinkle, twinkle, little star, \n\tHow I wonder what you are");
# Out:
#   File "C:\Users\fazee\AppData\Local\Temp/ipykernel_14060/3514119689.py", line 1
#     print("Twinkle, twinkle, little star, \n\tHow I wonder what you are! \n\t\t\Up above the world so high, \n\ttwinkle, twinkle, little star, \n\tHow I wonder what you are");
#                                                                                                                                                                              ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 68-69: truncated \UXXXXXXXX escape

# %%
import sys
print("python version")
print(sys.version)
print("version info.")
print(sys.version_info)
# Out:
# python version
# 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
# version info.
# sys.version_info(major=3, minor=9, micro=7, releaselevel='final', serial=0)

# %%
import datetime
now=datetime.datetime.now()
print("current date and time : ")
print(now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# current date and time :
# 2022-01-03 20:33:53

# %%
from math import pi
r = float(input("Input the radius of the circle : "))
print ("The area of the circle with radius " + str(r) + "is: " + str(pi * r**2))
# Out:
# Input the radius of the circle : 50
# The area of the circle with radius 50.0is: 7853.981633974483

# %%
A = ("Input your first name : ")
B = ("Input your last name : ")
print ("Hello " + A + " " + B)
# Out:
# Hello Input your first name :  Input your last name :

# %%
A = ("Input your first name :Muhammad Fazeel ")
B = ("Input your last name :Khan Warsi ")
print ("Hello " + A + " " + B)
# Out:
# Hello Input your first name :Muhammad Fazeel  Input your last name :Khan Warsi

# %%
a=8;
b=5;
z=a+b;
print(z);
# Out:
# 13
